# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
list_file = os.listdir(path=".") # получение списка файлов в папке

# %%
for file in list_file:
    if '.csv' in file: # если у файла расширение .csv, то читаем его как DF
        df_temp = pd.read_csv(file)
        df = pd.concat([df, df_temp], ignore_index=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (11,26,27,28,29,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop_duplicates(subset=['car_url']) # удаление дубликатов по URL объявления

# %%
df = df.replace('{}',  None) # замена пустых словарей на NaN
df['mileage'] = df['mileage'].apply(lambda x: int(x) if type(x) == str else x) # приведение 'mileage' к числовму виду
df = df.replace(np.nan,  None)

# %%
cols_int16 = ['modelDate', 'productionDate']
df[cols_int16] = df[cols_int16].astype('int16')

cols_int32 = ['mileage', 'sell_id', 'price', 'parsing_unixtime']
df[cols_int32] = df[cols_int32].astype('int32')

df['numberOfDoors'] = df['numberOfDoors'].astype('int8')

# %%
df
# Out:
#                 bodyType       brand  \
# 0              кабриолет    MERCEDES
# 1              кабриолет        FORD
# 2          хэтчбек 3 дв.        FORD
# 3                  седан     PACKARD
# 4          хэтчбек 3 дв.        FORD
# ...                  ...         ...
# 65596  внедорожник 5 дв.       VOLVO
# 65597  внедорожник 5 дв.  VOLKSWAGEN
# 65598  внедорожник 5 дв.  MITSUBISHI
# 65599              седан    MERCEDES
# 65600              седан        AUDI
#
#                                                  car_url        color  \
# 0      https://auto.ru/cars/used/sale/mercedes/simple...        белый
# 1      https://auto.ru/cars/used/sale/ford/model_t/10...      зелёный
# 2      https://auto.ru/cars/used/sale/ford/model_a/10...        синий
# 3      https://auto.ru/cars/used/sale/packard/six/107...       чёрный
# 4      https://auto.ru/cars/used/sale/ford/model_a/11...      бежевый
# ...                                                  ...          ...
# 65596  https://auto.ru/cars/new/group/volvo/xc40/2131...        белый
# 65597  https://auto.ru/cars/new/group/volkswagen/toua...        синий
# 65598  https://auto.ru/cars/new/group/mitsubishi/outl...       чёрный
# 65599  https://auto.ru/cars/new/group/mercedes/cla_kl...  серебристый
# 65600  https://auto.ru/cars/new/group/audi/a6/2159379...       чёрный
#
#                                       complectation_dict  \
# 0                                             {"id":"0"}
# 1                                             {"id":"0"}
# 2                                             {"id":"0"}
# 3                                             {"id":"0"}
# 4                                             {"id":"0"}
# ...                                                  ...
# 65596  {"id":"22175422","name":"Momentum","available_...
# 65597  {"id":"21711645","name":"Business","available_...
# 65598  {"id":"21397687","name":"Instyle","available_o...
# 65599  {"id":"21925758","name":"CLA 200 Sport","avail...
# 65600  {"id":"21594143","name":"45 TFSI quattro S tro...
#
#                                              description engineDisplacement  \
# 0      на ходу. 1904 год. стоит в гараже, пылится.Кат...            5.3 LTR
# 1      1 октября 1908 Форд воплотил в жизнь свою мечт...            2.9 LTR
# 2      Машина растаможена в лоб\nНалог низкий\nМотор ...            3.3 LTR
# 3      автомобиль 1927 года выпуска, полностью в ориг...            4.7 LTR
# 4      Это Форд А 28 года. Только перебран двигатель....            3.3 LTR
# ...                                                  ...                ...
# 65596  Узнайте вашу выгоду на автомобили VOLVO в Inch...            2.0 LTR
# 65597  [Polo]\n\n[Tiguan]\n\n[Jetta]\n\n[Passat]\n\nС...            3.0 LTR
# 65598  РОЛЬФ Восток Mitsubishi – официальный дилер Mi...            2.4 LTR
# 65599  Комплектация CLA 200 Sport\n\n\nПредложение об...            1.3 LTR
# 65600  Только в декабре Ауди Центр Варшавка дарит зим...            2.0 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 0          32 N12                                                NaN   бензин
# 1          20 N12                                                NaN   бензин
# 2          40 N12                                                NaN   бензин
# 3          60 N12                            {"20-inch-wheels":true}   бензин
# 4          40 N12                            {"20-inch-wheels":true}   бензин
# ...           ...                                                ...      ...
# 65596     190 N12  {"cruise-control":true,"asr":true,"esp":true,"...   бензин
# 65597     249 N12  {"asr":true,"esp":true,"usb":true,"multi-wheel...   дизель
# 65598     167 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
# 65599     150 N12  {"cruise-control":true,"asr":true,"esp":true,"...   бензин
# 65600     245 N12  {"cruise-control":true,"glonass":true,"asr":tr...   бензин
#
#        ...              vehicleConfiguration  vehicleTransmission    vendor  \
# 0      ...             CABRIO MECHANICAL 5.3         механическая  EUROPEAN
# 1      ...             CABRIO MECHANICAL 2.9         механическая  AMERICAN
# 2      ...  HATCHBACK_3_DOORS MECHANICAL 3.3         механическая  AMERICAN
# 3      ...              SEDAN MECHANICAL 4.7         механическая  AMERICAN
# 4      ...  HATCHBACK_3_DOORS MECHANICAL 3.3         механическая  AMERICAN
# ...    ...                               ...                  ...       ...
# 65596  ...     ALLROAD_5_DOORS AUTOMATIC 2.0       автоматическая  EUROPEAN
# 65597  ...     ALLROAD_5_DOORS AUTOMATIC 3.0       автоматическая  EUROPEAN
# 65598  ...      ALLROAD_5_DOORS VARIATOR 2.4             вариатор  JAPANESE
# 65599  ...                   SEDAN ROBOT 1.3     роботизированная  EUROPEAN
# 65600  ...                   SEDAN ROBOT 2.0     роботизированная  EUROPEAN
#
#         Владельцы            Владение       ПТС  Привод    Руль  \
# 0      1 владелец  6 лет и 10 месяцев  Оригинал  задний  Правый
# 1      1 владелец  6 лет и 10 месяцев  Оригинал  задний   Левый
# 2      1 владелец  13 лет и 7 месяцев  Оригинал  задний   Левый
# 3      1 владелец  13 лет и 7 месяцев  Оригинал  задний   Левый
# 4      1 владелец  13 лет и 7 месяцев  Оригинал  задний   Левый
# ...           ...                 ...       ...     ...     ...
# 65596  1 владелец             1 месяц  Оригинал  задний   Левый
# 65597  1 владелец             1 месяц  Оригинал  задний   Левый
# 65598  1 владелец             1 месяц  Оригинал  задний   Левый
# 65599  1 владелец             1 месяц  Оригинал  задний   Левый
# 65600  1 владелец             1 месяц  Оригинал  задний   Левый
#
#                 Состояние     Таможня
# 0      Не требует ремонта  Растаможен
# 1      Не требует ремонта  Растаможен
# 2      Не требует ремонта  Растаможен
# 3      Не требует ремонта  Растаможен
# 4      Не требует ремонта  Растаможен
# ...                   ...         ...
# 65596  Не требует ремонта  Растаможен
# 65597  Не требует ремонта  Растаможен
# 65598  Не требует ремонта  Растаможен
# 65599  Не требует ремонта  Растаможен
# 65600  Не требует ремонта  Растаможен
#
# [63926 rows x 32 columns]

# %%
df.to_csv('auto_ru_moskva_12_12_2020.csv', encoding = 'utf-8', index=False)
